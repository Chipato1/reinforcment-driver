# %% [markdown]
# # COMP47590 Advanced Machine Learning

# %% [markdown]
# ## Assignment 2: Going the Distance
# Uses the PPO actor-critic method to train a neural network to control a simple robot in the RacingCar environment from OpenAI gym (https://gym.openai.com/envs/RacingCar-v0/).

# %% [markdown]
# ![Racing](racing_car.gif)
#
# There are five discrete **actions** in this environment:
# - left (0)
# - right (1)
# - brake (2)
# - accelerate (3)
# - none (4)
#
# **Reward** of -0.1 is awarded every frame and +1000/N for every track tile visited, where N is the total number of tiles in track. For example, if you have finished in 732 frames, your reward is 1000 - 0.1*732 = 926.8 points.
#
# And the **state** is represented using a single image frame (96 * 96).

# %% [markdown]
# ### Initialisation

# %% [markdown]
# If using Google colab you need to install packages - comment out lines below.

# %%
#!apt install swig cmake ffmpeg
#!apt-get install -y xvfb x11-utils
#!pip install stable-baselines3[extra] pyglet box2d box2d-kengz
#!pip install pyvirtualdisplay PyOpenGL PyOpenGL-accelerate

# %% [markdown]
# For Google colab comment out this cell to make a virtual rendering canvas so render calls work (we still won't see display!)

# %%
#import pyvirtualdisplay
#
#_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
#                                    size=(1400, 900))
#_ = _display.start()

# %% [markdown]
# Import required packages.

# %%
import torch 
import gym
import stable_baselines3 as sb3

import pandas as pd # For data frames and data frame manipulation
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)
import numpy as np # For general  numeric operations

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tetris-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tetris-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pong-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KeystoneKapers-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KeystoneKapers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Blackjack-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Blackjack-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Zaxxon-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Zaxxon-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Berzerk-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Berzerk-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LaserGates-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LaserGates-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LostLuggage-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/LostLuggage-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/RoadRunner-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/RoadRunner-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DemonAttack-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DemonAttack-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kaboom-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kaboom-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/IceHockey-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/IceHockey-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Venture-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Venture-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/YarsRevenge-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/YarsRevenge-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Othello-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Othello-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Adventure-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Adventure-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videochess-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videochess-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MrDo-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MrDo-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Riverraid-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Riverraid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frostbite-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frostbite-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TimePilot-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TimePilot-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Bowling-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Bowling-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Assault-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Assault-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Boxing-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Boxing-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hangman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hangman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis2-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis2-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall2-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pitfall2-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hero-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Hero-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ChopperCommand-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ChopperCommand-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/JourneyEscape-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/JourneyEscape-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Earthworld-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Earthworld-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Casino-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Casino-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Koolaid-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Koolaid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MiniatureGolf-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MiniatureGolf-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KungFuMaster-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KungFuMaster-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Jamesbond-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Jamesbond-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BasicMath-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BasicMath-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceWar-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceWar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FlagCapture-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FlagCapture-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TicTacToe3D-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/TicTacToe3D-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Surround-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Surround-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DoubleDunk-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DoubleDunk-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KingKong-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/KingKong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BankHeist-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BankHeist-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asteroids-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asteroids-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/UpNDown-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/UpNDown-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MsPacman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MsPacman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Et-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Et-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BeamRider-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BeamRider-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tennis-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tennis-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Robotank-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Robotank-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceInvaders-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SpaceInvaders-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Enduro-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Enduro-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gopher-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gopher-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/NameThisGame-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/NameThisGame-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Qbert-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Qbert-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tutankham-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Tutankham-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Phoenix-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Phoenix-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gravitar-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Gravitar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Trondead-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Trondead-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WordZapper-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WordZapper-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Superman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Superman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ElevatorAction-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/ElevatorAction-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Entombed-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Entombed-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Solaris-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Solaris-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Amidar-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Amidar-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Crossbow-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Crossbow-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Skiing-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Skiing-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pacman-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pacman-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Centipede-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Centipede-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DonkeyKong-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/DonkeyKong-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Backgammon-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Backgammon-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FishingDerby-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/FishingDerby-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Alien-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Alien-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Klax-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Klax-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HauntedHouse-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HauntedHouse-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BattleZone-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/BattleZone-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frogger-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Frogger-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videocube-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Videocube-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Carnival-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Carnival-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/AirRaid-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/AirRaid-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Atlantis-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/StarGunner-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/StarGunner-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoCheckers-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoCheckers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Breakout-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Breakout-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MontezumaRevenge-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MontezumaRevenge-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WizardOfWor-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/WizardOfWor-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Galaxian-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Galaxian-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pooyan-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Pooyan-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Defender-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Defender-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SirLancelot-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/SirLancelot-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MarioBros-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/MarioBros-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HumanCannonball-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/HumanCannonball-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kangaroo-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Kangaroo-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asterix-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Asterix-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Freeway-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Freeway-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Seaquest-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Seaquest-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Darkchambers-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Darkchambers-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/CrazyClimber-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/CrazyClimber-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoPinball-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/VideoPinball-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Krull-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Krull-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Turmoil-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/Turmoil-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/PrivateEye-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ALE/PrivateEye-ram-v5
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AdventureDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AdventureNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AdventureDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AdventureNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Adventure-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaidDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaidNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaidDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaidNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AirRaid-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AlienDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AlienNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AlienDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AlienNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Alien-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Amidar-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AmidarDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment AmidarNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# ...
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment TutankhamDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment TutankhamNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Tutankham-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDownDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDownNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDownDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDownNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment UpNDown-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VentureNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Venture-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinballNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment VideoPinball-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWorNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment WizardOfWor-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevengeNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment YarsRevenge-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment ZaxxonNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ram-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramDeterministic-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramNoFrameskip-v0
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ram-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramDeterministic-v4
#   logger.warn("Overriding environment {}".format(id))
# /home/chipato/.local/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment Zaxxon-ramNoFrameskip-v4
#   logger.warn("Overriding environment {}".format(id))

# %% [markdown]
# ### Create and Explore the Environment

# %% [markdown]
# Create the **CarRacing-v0** environment. Add wrappers to resize the images and convert to greyscale.

# %%
env = gym.make('CarRacing-v0')
env = gym.wrappers.resize_observation.ResizeObservation(env, 64)
env = gym.wrappers.gray_scale_observation.GrayScaleObservation(env, keep_dim = True)

# %% [markdown]
# Explore the environment - view the action space and observation space.

# %%
env.action_space.shape
# Out:
# (3,)

# %%
env.observation_space.shape
# Out:
# (64, 64, 1)

# %% [markdown]
# Play an episode of the environment using random actions

# %%
# Add code here
obs = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
    env.render()
    env.render('rgb_array')
# Out:
# Track generation: 1269..1598 -> 329-tiles track

# %% [markdown]
# ### Single Image Agent
# Create an agent that controls the car using a single image frame as the state input. We recommend a PPO agent with the following hyper-parameters (although you can experiment):
# - learning_rate = 3e-5
# - n_steps = 512
# - ent_coef = 0.001
# - batch_size = 128
# - gae_lambda =  0.9
# - n_epochs = 20
# - use_sde = True
# - sde_sample_freq = 4
# - clip_range = 0.4
# - policy_kwargs = {'log_std_init': -2, 'ortho_init':False},
#
# We also recommend enabling **tensorboard** monitoring of the training process.

# %%
# Add code here
tb_log = './log_racing_PPO/'
agent = sb3.PPO('MlpPolicy', env,
                    learning_rate = 3e-5,
                    n_steps = 512,
                    ent_coef = 0.001,
                    batch_size = 128,
                    gae_lambda =  0.9,
                    n_epochs = 20,
                    use_sde = True,
                    sde_sample_freq = 4,
                    clip_range = 0.4,
                    policy_kwargs = {'log_std_init': -2, 'ortho_init':False},
                    tensorboard_log=tb_log)

# %% [markdown]
# Examine the actor and critic network architectures.

# %%
# Add code here

# @David-> I dont really know what to do here....
print(agent.policy)
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (shared_net): Sequential()
#     (policy_net): Sequential(
#       (0): Linear(in_features=4096, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=4096, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=3, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# Create an evaluation callback that is called every at regular intervals and renders the episode.

# %%
# Use a separate evaluation env in case any wrappers have been used
#eval_env = gym.make('CarRacing-v0') 
eval_callback = sb3.common.callbacks.EvalCallback(env, 
                                                  best_model_save_path='./logs_racing1/',
                                                  log_path=tb_log, 
                                                  eval_freq=5000,
                                                  render=True)

# %% [markdown]
# Train the model for a large number of timesteps (500,000 timesteps will probably work well).

# %%
# Add code here
agent.learn(total_timesteps=500000,callback=eval_callback)
# Out:
# Track generation: 1147..1441 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1116..1399 -> 283-tiles track
# /home/chipato/.local/lib/python3.8/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7fec9ba49370> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fec9ba49730>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Track generation: 1228..1540 -> 312-tiles track
# Track generation: 1260..1579 -> 319-tiles track
# Track generation: 1127..1420 -> 293-tiles track
# Track generation: 1136..1428 -> 292-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1305..1635 -> 330-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1097..1381 -> 284-tiles track
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12041/2088591377.py in <module>
#       1 # Add code here
# ----> 2 agent.learn(total_timesteps=500000,callback=eval_callback)
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     302     ) -> "PPO":
#     303
# --> 304         return super(PPO, self).learn(
#     305             total_timesteps=total_timesteps,
#     306             callback=callback,
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     248         while self.num_timesteps < total_timesteps:
#     249
# --> 250             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     251
#     252             if continue_training is False:
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     182             # Give access to local variables
#     183             callback.update_locals(locals())
# --> 184             if callback.on_step() is False:
#     185                 return False
#     186
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/callbacks.py in on_step(self)
#      86         self.num_timesteps = self.model.num_timesteps
#      87
# ---> 88         return self._on_step()
#      89
#      90     def on_training_end(self) -> None:
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/callbacks.py in _on_step(self)
#     391             self._is_success_buffer = []
#     392
# --> 393             episode_rewards, episode_lengths = evaluate_policy(
#     394                 self.model,
#     395                 self.eval_env,
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      84     episode_starts = np.ones((env.num_envs,), dtype=bool)
#      85     while (episode_counts < episode_count_targets).any():
# ---> 86         actions, states = model.predict(observations, state=states, episode_start=episode_starts, deterministic=deterministic)
#      87         observations, rewards, dones, infos = env.step(actions)
#      88         current_rewards += rewards
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/base_class.py in predict(self, observation, state, episode_start, deterministic)
#     560             (used in recurrent policies)
#     561         """
# --> 562         return self.policy.predict(observation, state, episode_start, deterministic)
#     563
#     564     def set_random_seed(self, seed: Optional[int] = None) -> None:
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/policies.py in predict(self, observation, state, episode_start, deterministic)
#     333         self.set_training_mode(False)
#     334
# --> 335         observation, vectorized_env = self.obs_to_tensor(observation)
#     336
#     337         with th.no_grad():
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/policies.py in obs_to_tensor(self, observation)
#     248         if not isinstance(observation, dict):
#     249             # Dict obs need to be handled separately
# --> 250             vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     251             # Add batch dimension if needed
#     252             observation = observation.reshape((-1,) + self.observation_space.shape)
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/utils.py in is_vectorized_observation(observation, observation_space)
#     373     for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     374         if isinstance(observation_space, space_type):
# --> 375             return is_vec_obs_func(observation, observation_space)
#     376     else:
#     377         # for-else happens if no break is called
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/utils.py in is_vectorized_box_observation(observation, observation_space)
#     240         return True
#     241     else:
# --> 242         raise ValueError(
#     243             f"Error: Unexpected observation shape {observation.shape} for "
#     244             + f"Box environment, please use {observation_space.shape} "
#
# ValueError: Error: Unexpected observation shape (1, 96, 96, 3) for Box environment, please use (1, 64, 64) or (n_env, 1, 64, 64) for the observation shape.

# %% [markdown]
# tensorboard --logdir  ./log_racing_PPO/
# http://localhost:6006/

# %% [markdown]
# Save the trained agent.

# %%
# Add code here

# %% [markdown]
# For memory management delete old agent and environment (assumes variable names - change if required).

# %%
del agent
del env
del eval_env

# %% [markdown]
# ### Create Image Stack Agent

# %% [markdown]
# Create the CarRacing-v0 environment using wrappers to resize the images to 64 x 64 and change to greyscale. Also add a wrapper to create a stack of 4 frames.

# %%
# Add code here

# %% [markdown]
# Create an agent that controls the car using a stack of input image frames as the state input. We recommend a PPO agent with the following hyper-parameters (although you can experiment):
# - learning_rate = 3e-5
# - n_steps = 512
# - ent_coef = 0.001
# - batch_size = 128
# - gae_lambda =  0.9
# - n_epochs = 20
# - use_sde = True
# - sde_sample_freq = 4
# - clip_range = 0.4
# - policy_kwargs = {'log_std_init': -2, 'ortho_init':False},
#
# We also recommend enabling **tensorboard** monitoring of the training process.

# %%
# Add code here

# %% [markdown]
# Examine the actor and critic network architectures.

# %%
# Add code here

# %% [markdown]
# Create an evaluation callback that is called every at regular intervals and renders the episode.

# %%
# Add code here

# %% [markdown]
# Train the model for a large number of timesteps (500,000 timesteps will probably work well).

# %%
# Add code here

# %% [markdown]
# Connect to the tensorboard log using **TensorBoard** from the command line to view training progress:
# ~~./log_tb_carracing_PPO/~~
# `tensorboard --logdir  ./log_racing_PPO/`
#
# Then open TensorBoard in a browser, typically located at:
#
# `http://localhost:6006/`

# %% [markdown]
# Save the trained agent.

# %%
# Add code here

# %% [markdown]
# For memory management delete old agent and environment (assumes variable names - change if required).

# %%
del agent
del env
del eval_env

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Load the single image saved agent

# %%
# Add code here

# %% [markdown]
# Setup the single image environment for evaluation.

# %%
# Add code here

# %% [markdown]
# Evaluate the agent in the environment for 30 episodes, rendering the process.

# %%
# Add code here

# %% [markdown]
# For memory management delete the single image agent (assumes variable names - change if required).

# %%
del agent
del eval_env

# %% [markdown]
# Load the image stack agent

# %%
# Add code here

# %% [markdown]
# Set up the image stack environment

# %%
# Add code here

# %% [markdown]
# Evaluate the agent in the environment for 30 episodes, rendering the process.

# %%
# Add code here

# %% [markdown]
# ### Reflection

# %% [markdown]
# Reflect on which  agent performs better at the task, and the training process involved (max 200 words).
